# %% [markdown]
# # News Summarization

# %% [markdown]
# ### Scrape the article you want to summarize

# %%
from scraping import return_single_article
article = return_single_article('https://www.aljazeera.com/economy/2025/6/30/how-generative-ai-is-affecting-peoples-minds')

# %%
print(article['title'], '\n\n')
print(article['authors'], '\n\n')
print(article['source'], '\n\n')
print(article['article'], '\n\n')
# Out:
# How generative AI is affecting people’s minds
#
#
# By Thor Benson
#
#
# aljazeera
#
#
# Researchers at Stanford University recently tested out some of the more popular AI tools on the market, from companies like OpenAI and Character.ai, and tested how they did at simulating therapy.
#
# The researchers found that when they imitated someone who had suicidal intentions, these tools were more than unhelpful — they failed to notice they were helping that person plan their own death.
#
# “[AI] systems are being used as companions, thought-partners, confidants, coaches, and therapists,” says Nicholas Haber, an assistant professor at the Stanford Graduate School of Education and senior author of the new study. “These aren’t niche uses – this is happening at scale.”
#
# AI is becoming more and more ingrained in people’s lives and is being deployed in scientific research in areas as wide-ranging as cancer and climate change. There is also some debate that it could cause the end of humanity.
# ...

# %% [markdown]
# ### Summarization

# %%
from hf_summarizer import bart_summarize

# %%
# this function uses this model: https://huggingface.co/sshleifer/distilbart-cnn-12-6
# which is a bert-like model trained on the cnn-dailymail dataset
# its one of the best summarization models available in transformers, very fast, good for deployment
summary = bart_summarize(article['article'])
# Out:
# c:\Users\Ismaeel\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from IPython.display import display, Markdown
import textwrap

if 'summary' in locals():
    formatted = textwrap.fill(summary, width=80)
    display(Markdown(f"**Summary:**\n\n{formatted}"))
else:
    print("No summary variable found.")
# Out:
# **Summary:**
#
#  Researchers at Stanford University tested some of the more popular AI tools on
# the market, from companies like OpenAI and Character.ai, and tested how they did
# at simulating therapy . They found that when they imitated someone who had
# suicidal intentions, these tools were more than unhelpful — they failed to
# notice they were helping that person plan their own death .

# %% [markdown]
# #### There are many other summary options available in hf_summarizer.py including different pegasus models, t5

# %% [markdown]
# ### Statistical Summarization

# %%
from statistical_summarize import run_statistical_summarizers

# %%
run_statistical_summarizers(text=article['article'], num_sentences=5)
# Out:
# **********Statistical Summarizations**********
#
#
# TF IDF Summary:
# There is also some debate that it could cause the end of humanity. Psychology experts, however, have many concerns about its potential impact. One concerning instance of how this is playing out can be seen on the popular community network Reddit. They give people what the programme thinks should follow next. People also need to be educated on what AI can do well and what it cannot do well.
#
#
# Word Frequency Summary:
# Psychology experts, however, have many concerns about its potential impact. “What we are seeing is there is the possibility that people can become cognitively lazy,” Aguilar says. Similar issues could arise for people with AI being used so often. People also need to be educated on what AI can do well and what it cannot do well. “We need more research,” says Aguilar.

# %% [markdown]
# #### These statistical techniques do not use any Machine Learning algorithms but are very fast and give a decent result

# %% [markdown]
# ### Sentiment Analysis

# %%
from sentiment_analysis import hf_topn_sentiment

# %%
# this function returns the top positive and top negative sentences from a piece of text,
# not exactly summarization but can get the most polarizing lines from an article
top_positive, top_negative = hf_topn_sentiment(article['article'])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From c:\Users\Ismaeel\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
top_positive
# Out:
# [(0.9955390095710754,
#   '“These aren’t niche uses – this is happening at scale.”\n\nAI is becoming more and more ingrained in people’s lives and is being deployed in scientific research in areas as wide-ranging as cancer and climate change.'),
#  (0.9957178235054016,
#   'They give people what the programme thinks should follow next.')]

# %%
top_negative
# Out:
# [(0.9995323419570923,
#   '“With schizophrenia, people might make absurd statements about the world, and these LLMs are a little too sycophantic.'),
#  (0.9995761513710022,
#   'A student who uses AI to write every paper for school is not going to learn as much as one that does not.')]
